# %%
import spacy

# %%
import pandas as pd

# %%
nlp = spacy.load('en_core_web_lg')

# %%
df = pd.read_csv('../data/review_data.csv')

# %%
df.head(n=50)
# Out:
#     Unnamed: 0                                              title  \
# 0            0  ['Last Drop Distillers XIX: 1980 Kentucky Stra...
# 1            1  ['Parker&#x27;s Heritage Collection: Promise o...
# 2            2                  ['Van Winkle Family Reserve Rye']
# 3            3  ['A. Smith Bowman Cask Strength Bourbon (Batch...
# 4            4                      ['Barrell Bourbon Batch 006']
# 5            5  ['Barrell Craft Spirits Gold Label Seagrass (2...
# 6            6                              ['Booker&#x27;s Rye']
# 7            7                           ['Elijah Craig 21 Year']
# 8            8                         ['George T. Stagg (2022)']
# 9            9                   ['George T. Stagg 2013 Release']
# 10          10  ['Heaven Hill Heritage Collection 17 Year Old ...
# 11          11              ['Larceny Barrel Proof (Batch C922)']
# 12          12  ['Lucky Seven â\x80\x9cThe Proprietorâ\x80\x9d...
# ...

# %%
df.release_date[2].replace('&nbsp', '')
# Out:
# "[';October 2013 / Yearly Release']"

# %%
import lxml.html.clean

# %%
lxml.html.clean.clean_html(df.nose[0])
# Out:
# "<p>['Toffee | Coconut | Leather | Tobacco leaf | Plum | Dark cherry | Graham cracker | Seasoned oak | Spice develops | Viscous mouthfeel with a complex delivery of flavors thatâ\\x80\\x99s rivaled by very few']</p>"

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(df.nose[0])
# Out:
# /home/cayler/PycharmProjects/whiskey-review/venv/lib/python3.9/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
soup.get_text()
# Out:
# "['Toffee | Coconut | Leather | Tobacco leaf | Plum | Dark cherry | Graham cracker | Seasoned oak | Spice develops | Viscous mouthfeel with a complex delivery of flavors thatâ\\x80\\x99s rivaled by very few']"

# %%
df.nose[0].encode('ascii', errors='ignore')
# Out:
# b"['Toffee | Coconut | Leather | Tobacco leaf | Plum | Dark cherry | Graham cracker | Seasoned oak | Spice develops | Viscous mouthfeel with a complex delivery of flavors that\\x80\\x99s rivaled by very few']"

# %%
import re

# %%
re.sub(r'[^\x00-\x7f]',r'', df.nose[0])
# Out:
# "['Toffee | Coconut | Leather | Tobacco leaf | Plum | Dark cherry | Graham cracker | Seasoned oak | Spice develops | Viscous mouthfeel with a complex delivery of flavors that\\x80\\x99s rivaled by very few']"
